# %%
# !pip install nltk

import nltk
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

text = "Natural language processing enables machines to understand human communication effectively."

tokens = word_tokenize(text)

stop_words = set(stopwords.words("english"))
filtered_tokens = [w for w in tokens if w.lower() not in stop_words]

lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(w.lower()) for w in filtered_tokens]

print("Tokens:", tokens)
print("Without Stopwords:", filtered_tokens)
print("Lemmatized Tokens:", lemmatized_tokens)
# Out:
# ...
# Tokens: ['Natural', 'language', 'processing', 'enables', 'machines', 'to', 'understand', 'human', 'communication', 'effectively', '.']
# Without Stopwords: ['Natural', 'language', 'processing', 'enables', 'machines', 'understand', 'human', 'communication', 'effectively', '.']
# Lemmatized Tokens: ['natural', 'language', 'processing', 'enables', 'machine', 'understand', 'human', 'communication', 'effectively', '.']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Pranjal\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Pranjal\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Pranjal\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
tokens = word_tokenize(text)

stop_words = set(stopwords.words("english"))
filtered_tokens = [w for w in tokens if w.lower() not in stop_words]

lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(w.lower()) for w in filtered_tokens]

# %%
text = "Natural language processing enables machines to understand human communication effectively."

# %%
print("Tokens:", tokens)
print("Without Stopwords:", filtered_tokens)
print("Lemmatized Tokens:", lemmatized_tokens)
# Out:
# Tokens: ['Natural', 'language', 'processing', 'enables', 'machines', 'to', 'understand', 'human', 'communication', 'effectively', '.']
# Without Stopwords: ['Natural', 'language', 'processing', 'enables', 'machines', 'understand', 'human', 'communication', 'effectively', '.']
# Lemmatized Tokens: ['natural', 'language', 'processing', 'enables', 'machine', 'understand', 'human', 'communication', 'effectively', '.']

# %%
import re
texts = re.sub(r'[^a-zA-Z\s]', '', text)
print("texts:", texts)
# Out:
# texts: Natural language processing enables machines to understand human communication effectively
